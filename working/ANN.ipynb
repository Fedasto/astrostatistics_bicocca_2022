# %% [markdown]
# - L2 regularization
# - Relu and Linear activation function
# - number of layers is between the input and the numbers of output neurons
# - Stopping the epoch earlier than the end

# %% [markdown]
# ![data_set_1.png](attachment:data_set_1.png)

# %% [markdown]
# ![data_set_2.png](attachment:data_set_2.png)
